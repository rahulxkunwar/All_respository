# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulxkunwar/All_respository/blob/master/Resources/Blank_SQL_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Int_SQL_Data_Analytics_Course/blob/main/Resources/Blank_SQL_Notebook.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Blank SQL Notebook
#
# #### Import Libraries & Database

# %%
import sys
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# If running in Google Colab, install PostgreSQL and restore the database
if 'google.colab' in sys.modules:
    # Update package installer
    # !sudo apt-get update -qq > /dev/null 2>&1

    # Install PostgreSQL
    # !sudo apt-get install postgresql -qq > /dev/null 2>&1

    # Start PostgreSQL service (suppress output)
    # !sudo service postgresql start > /dev/null 2>&1

    # Set password for the 'postgres' user to avoid authentication errors (suppress output)
    # !sudo -u postgres psql -c "ALTER USER postgres WITH PASSWORD 'password';" > /dev/null 2>&1

    # Create the 'colab_db' database (suppress output)
    # !sudo -u postgres psql -c "CREATE DATABASE contoso_100k;" > /dev/null 2>&1

    # Download the PostgreSQL .sql dump
    # !wget -q -O contoso_100k.sql https://github.com/lukebarousse/Int_SQL_Data_Analytics_Course/releases/download/v.0.0.0/contoso_100k.sql

    # Restore the dump file into the PostgreSQL database (suppress output)
    # !sudo -u postgres psql contoso_100k < contoso_100k.sql > /dev/null 2>&1

    # Shift libraries from ipython-sql to jupysql
    # !pip uninstall -y ipython-sql > /dev/null 2>&1
    # !pip install jupysql > /dev/null 2>&1

# Load the sql extension for SQL magic
# %load_ext sql

# Connect to the PostgreSQL database
# %sql postgresql://postgres:password@localhost:5432/contoso_100k

# Enable automatic conversion of SQL results to pandas DataFrames
# %config SqlMagic.autopandas = True

# Disable named parameters for SQL magic
# %config SqlMagic.named_parameters = "disabled"

# Display pandas number to two decimal places
pd.options.display.float_format = '{:.2f}'.format
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# Connecting and switching to connection 'postgresql://postgres:***@localhost:5432/contoso_100k'

# %%
# %%sql
#
# SELECT table_name
# FROM information_schema.tables
# WHERE table_schema='public'
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/contoso_100k'
# 6 rows affected.
#          table_name
# 0  currencyexchange
# 1          customer
# 2             sales
# 3              date
# 4           product
# 5             store

# %%
# %%sql
#
# SELECT
#   s.orderdate,
#   COUNT(DISTINCT(CASE WHEN c.continent = 'Europe' THEN s.customerkey END)) AS eu_customers,
#   COUNT(DISTINCT(CASE WHEN c.continent = 'North America' THEN s.customerkey END)) AS na_customers,
#   COUNT(DISTINCT(CASE WHEN c.continent = 'Australia' THEN s.customerkey END)) AS au_customers,
#   COUNT(DISTINCT(s.customerkey)) AS total_customers
# FROM
#   sales s
# LEFT JOIN customer c ON s.customerkey = c.customerkey
# WHERE
#   s.orderdate BETWEEN '2023-01-01' AND '2023-12-31'
# GROUP BY
#   s.orderdate
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/contoso_100k'
# 364 rows affected.
#       orderdate  eu_customers  na_customers  au_customers  total_customers
# 0    2023-01-01             6             5             1               12
# 1    2023-01-02            15            31             3               49
# 2    2023-01-03            17            44             3               64
# 3    2023-01-04            28            46             4               78
# 4    2023-01-05            22            57             8               87
# ..          ...           ...           ...           ...              ...
# 359  2023-12-27            26            41             6               73
# 360  2023-12-28            24            44             7               75
# 361  2023-12-29            19            32             4               55
# 362  2023-12-30            25            50            16               91
# 363  2023-12-31             1             8             0                9
#
# [364 rows x 5 columns]

# %%
# %%sql
#
# SELECT
#   p.categoryname,
#   SUM(CASE WHEN s.orderdate BETWEEN '2022-01-01' AND '2022-12-31' THEN s.quantity * s.netprice * s.exchangerate ELSE 0 END) AS total_net_revenue2022,
#   SUM(CASE WHEN s.orderdate BETWEEN '2023-01-01' AND '2023-12-31' THEN s.quantity * s.netprice * s.exchangerate ELSE 0 END) AS total_net_revenue2023
# FROM
#   sales AS s
# LEFT JOIN product AS p ON s.productkey = p.productkey
# GROUP BY
#   p.categoryname
# ORDER BY
#   p.categoryname
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/contoso_100k'
# 8 rows affected.
#                     categoryname  total_net_revenue2022  total_net_revenue2023
# 0                          Audio              766938.21              688690.18
# 1        Cameras and camcorders              2382532.56             1983546.29
# 2                    Cell phones             8119665.07             6002147.63
# 3                      Computers            17862213.49            11650867.21
# 4                 Games and Toys              316127.30              270374.96
# 5                Home Appliances             6612446.68             5919992.87
# 6  Music, Movies and Audio Books             2989297.28             2180768.13
# 7                   TV and Video             5815336.61             4412178.23

# %%
# %%sql
#
# SELECT * FROM product
# LIMIT 25
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/contoso_100k'
# 25 rows affected.
#     productkey  productcode  \
# 0            1       101001
# 1            2       101002
# 2            3       101003
# 3            4       101004
# 4            5       101005
# 5            6       101006
# 6            7       101007
# 7            8       101008
# 8            9       101009
# 9           10       101010
# 10          11       101011
# 11          12       101012
# 12          13       101013
# 13          14       101014
# 14          15       101015
# 15          16       101016
# 16          17       101017
# 17          18       101018
# 18          19       101019
# 19          20       101020
# 20          21       101021
# 21          22       101022
# 22          23       101023
# 23          24       101024
# 24          25       101025
#
#                                           productname  manufacturer    brand  \
# 0                 Contoso 512MB MP3 Player E51 Silver  Contoso, Ltd  Contoso
# 1                   Contoso 512MB MP3 Player E51 Blue  Contoso, Ltd  Contoso
# 2                    Contoso 1G MP3 Player E100 White  Contoso, Ltd  Contoso
# 3                   Contoso 2G MP3 Player E200 Silver  Contoso, Ltd  Contoso
# 4                      Contoso 2G MP3 Player E200 Red  Contoso, Ltd  Contoso
# 5                    Contoso 2G MP3 Player E200 Black  Contoso, Ltd  Contoso
# 6                     Contoso 2G MP3 Player E200 Blue  Contoso, Ltd  Contoso
# 7                   Contoso 4G MP3 Player E400 Silver  Contoso, Ltd  Contoso
# 8                    Contoso 4G MP3 Player E400 Black  Contoso, Ltd  Contoso
# 9                    Contoso 4G MP3 Player E400 Green  Contoso, Ltd  Contoso
# 10                  Contoso 4G MP3 Player E400 Orange  Contoso, Ltd  Contoso
# 11             Contoso 4GB Flash MP3 Player E401 Blue  Contoso, Ltd  Contoso
# 12            Contoso 4GB Flash MP3 Player E401 Black  Contoso, Ltd  Contoso
# 13           Contoso 4GB Flash MP3 Player E401 Silver  Contoso, Ltd  Contoso
# 14            Contoso 4GB Flash MP3 Player E401 White  Contoso, Ltd  Contoso
# 15  Contoso 8GB Super-Slim MP3/Video Player M800 W...  Contoso, Ltd  Contoso
# 16   Contoso 8GB Super-Slim MP3/Video Player M800 Red  Contoso, Ltd  Contoso
# 17  Contoso 8GB Super-Slim MP3/Video Player M800 G...  Contoso, Ltd  Contoso
# 18  Contoso 8GB Super-Slim MP3/Video Player M800 Pink  Contoso, Ltd  Contoso
# 19        Contoso 8GB MP3 Player new model M820 Black  Contoso, Ltd  Contoso
# 20         Contoso 8GB MP3 Player new model M820 Blue  Contoso, Ltd  Contoso
# 21       Contoso 8GB MP3 Player new model M820 Yellow  Contoso, Ltd  Contoso
# 22        Contoso 8GB MP3 Player new model M820 White  Contoso, Ltd  Contoso
# 23                 Contoso 16GB Mp5 Player M1600 Blue  Contoso, Ltd  Contoso
# 24                Contoso 16GB Mp5 Player M1600 Black  Contoso, Ltd  Contoso
#
#      color weightunit  weight  cost  price  categorykey categoryname  \
# 0   Silver     ounces    4.80  6.62  12.99            1        Audio
# 1     Blue     ounces    4.10  6.62  12.99            1        Audio
# 2    White     ounces    4.50  7.40  14.52            1        Audio
# 3   Silver     ounces    4.50 11.00  21.57            1        Audio
# 4      Red     ounces    2.40 11.00  21.57            1        Audio
# 5    Black     ounces    8.80 11.00  21.57            1        Audio
# 6     Blue     ounces    2.10 11.00  21.57            1        Audio
# 7   Silver     ounces    5.60 30.58  59.99            1        Audio
# 8    Black     ounces    2.10 30.58  59.99            1        Audio
# 9    Green     ounces   11.00 30.58  59.99            1        Audio
# 10  Orange     ounces   14.10 30.58  59.99            1        Audio
# 11    Blue     ounces    7.40 35.72  77.68            1        Audio
# 12   Black     ounces    2.60 35.72  77.68            1        Audio
# 13  Silver     ounces    8.00 35.72  77.68            1        Audio
# 14   White     ounces    2.10 35.72  77.68            1        Audio
# 15   White     ounces   11.00 50.56 109.95            1        Audio
# 16     Red     ounces   11.00 50.56 109.95            1        Audio
# 17   Green     ounces    2.10 50.56 109.95            1        Audio
# 18    Pink     ounces    5.90 50.56 109.95            1        Audio
# 19   Black     pounds    1.00 61.62 134.00            1        Audio
# 20    Blue     ounces   10.60 61.62 134.00            1        Audio
# 21  Yellow     ounces    1.00 61.62 134.00            1        Audio
# 22   White     ounces    2.60 61.62 134.00            1        Audio
# 23    Blue     ounces   11.00 91.93 199.90            1        Audio
# 24   Black     ounces    5.90 91.93 199.90            1        Audio
#
#     subcategorykey subcategoryname
# 0              101         MP4&MP3
# 1              101         MP4&MP3
# 2              101         MP4&MP3
# 3              101         MP4&MP3
# 4              101         MP4&MP3
# 5              101         MP4&MP3
# 6              101         MP4&MP3
# 7              101         MP4&MP3
# 8              101         MP4&MP3
# 9              101         MP4&MP3
# 10             101         MP4&MP3
# 11             101         MP4&MP3
# 12             101         MP4&MP3
# 13             101         MP4&MP3
# 14             101         MP4&MP3
# 15             101         MP4&MP3
# 16             101         MP4&MP3
# 17             101         MP4&MP3
# 18             101         MP4&MP3
# 19             101         MP4&MP3
# 20             101         MP4&MP3
# 21             101         MP4&MP3
# 22             101         MP4&MP3
# 23             101         MP4&MP3
# 24             101         MP4&MP3
